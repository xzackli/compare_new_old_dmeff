# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import matplotlib.pyplot as plt

# %%
ttcmb = np.load('output/dmeffcmb.npy')
ttkboddy = np.load('output/kboddy.npy')
fid = np.load('output/fid.npy')

plt.plot(ttkboddy / fid, "-", label="kboddy/class_public dmeff")
plt.plot(ttcmb / fid, "--", label="DMeff-CMB")
plt.legend()
plt.title("1 GeV, baryons")
plt.ylabel(r"$(C_{\ell}^{\mathrm{dmeff}} / C_{\ell}^{\mathrm{fid}}) |_{\sigma_p = 2 \times 10^{-26} \, \mathrm{cm}^2}$")
# Out:
# /home/zequnl/anaconda3/envs/ps/lib/python3.7/site-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """
# /home/zequnl/anaconda3/envs/ps/lib/python3.7/site-packages/ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
# Text(0, 0.5, '$(C_{\\ell}^{\\mathrm{dmeff}} / C_{\\ell}^{\\mathrm{fid}}) |_{\\sigma_p = 2 \\times 10^{-26} \\, \\mathrm{cm}^2}$')
